# %%
import gym
from gym import envs
from gym import wrappers

import numpy as np
import sys
from collections import defaultdict

if "../" not in sys.path:
  sys.path.append("../")

import plotting

import matplotlib
matplotlib.style.use('ggplot')

# %%
def epsilon_greedy_policy(Q, state, num_actions, epsilon):
    policy = np.ones(num_actions, dtype=float) * epsilon / num_actions
    best_action = np.argmax(Q[state])
    policy[best_action] += 1-epsilon
    return policy

# %%
def learn(env_n, num_episodes,\
        outdir,\
        Q= defaultdict(lambda: np.zeros(env.action_space.n)),\
        discount_factor = 0.8,\
        lambda_factor = 0.9,\
        replacing_traces=True,\
        folder_options = '',\
        delete_content=False,\
        monitor=False):
    envi = gym.make(env_n)
    outdir = outdir + env_n + folder_options + "/"
    global env
    env = (wrappers.Monitor(envi, outdir, video_callable=False, force=delete_content) if monitor else envi)
    
    er = np.zeros(num_episodes)
    el = np.zeros(num_episodes)
    
    for i_episode in range(1,num_episodes+1):
        if (i_episode%1000)==0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()

        #initialization: use a list of (state, action) pair to keep
        #track of the episode "history"
        episode = []
        E = defaultdict(lambda: np.zeros(env.action_space.n))
        alpha = 1 - i_episode/num_episodes #0.04
        epsilon = (1 - i_episode/num_episodes) ** 2
        #initial state
        state = env.reset()
        #calculate the e-greedy policy for the init state given the Q function
        #and choose the action accordingly
        policy = epsilon_greedy_policy(Q, state, env.action_space.n, epsilon)
        action = np.random.choice(np.array(len(policy)), p=policy)
        while True:
            if ((state, action) not in episode):
                episode.append((state, action))
            next_state, reward, done, _= env.step(action)
            r = -1 if (done and reward==0) else reward
            policy = epsilon_greedy_policy(Q, next_state, env.action_space.n, epsilon)
            next_action = np.random.choice(np.array(len(policy)), p=policy)
            delta = r + discount_factor * Q[next_state][next_action] - Q[state][action]
            
            # Update statistics
            # Update statistics
            er[i_episode-1] += reward
            el[i_episode-1] += 1

            #updating the trace using the replacing or the eligibility
            if replacing_traces:
                E[state][action]  = 1
            else:
                E[state][action]  += 1

            #improvement of the Q value function for each state visited in the current episode
            for (states, actions) in episode:
                Q[states][actions] = Q[states][actions] + alpha * delta * E[states][actions]
                E[states][actions] = discount_factor * lambda_factor * E[states][actions]
                
            
            state = next_state; action = next_action;
            if done:
                break
    env.close()
    return Q, er, el

# %%
def calc_stats(er, el):
    
    #Calculate the mean of 100 consecutive episode reward and lengths
    
    num_episodes = len(er)
    stats = plotting.EpisodeStats(
        episode_lengths=np.zeros(num_episodes-100),\
        episode_rewards=np.zeros(num_episodes-100))
    
    for i in range(num_episodes - 100):
        stats.episode_rewards[i] = np.mean(er[i:i+100])
        stats.episode_lengths[i] = np.mean(el[i:i+100])
    return stats

# %%
if __name__ == '__main__':
    
    Q, er, el = learn(
        env_n='FrozenLake-v0',\
        num_episodes=1000,\
        outdir= "/Users/jacopo/openaigym/project/TD/results/SARSA_Lambda/",\
        replacing_traces=True,\
        folder_options = '1000',\
        delete_content=True,\
        monitor=True)
# Out:
# [2017-01-28 17:29:38,163] Making new env: FrozenLake-v0
# [2017-01-28 17:29:38,173] DEPRECATION WARNING: env.spec.timestep_limit has been deprecated. Replace your call to `env.spec.timestep_limit` with `env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')`. This change was made 12/28/2016 and is included in version 0.7.0
# [2017-01-28 17:29:38,175] Clearing 2 monitor files from previous run (because force=True was provided)
# Episode 10000/10000.
# [2017-01-28 17:29:45,892] Finished writing results. You can upload them to the scoreboard via gym.upload('/Users/jacopo/openaigym/project/TD/results/SARSA_Lambda/FrozenLake-v010000')

# %%
gym.upload("/Users/jacopo/openaigym/project/TD/results/SARSA_Lambda/FrozenLake-v010000")
# Out:
# [2017-01-28 16:52:46,825] [FrozenLake-v0] Uploading 10000 episodes of training data
# [2017-01-28 16:52:46,839] An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 196))
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-46-1fa70552aba2> in <module>()
# ----> 1 gym.upload("/Users/jacopo/openaigym/project/TD/results/SARSA_Lambda/FrozenLake-v010000")
#
# /Users/jacopo/openaigym/gym/gym/scoreboard/api.py in upload(training_dir, algorithm_id, writeup, tags, benchmark_id, api_key, ignore_open_monitors)
#      81         # Single evalution upload
#      82         benchmark_run_id = None
# ---> 83         evaluation = _upload(training_dir, algorithm_id, writeup, benchmark_run_id, api_key, ignore_open_monitors)
#      84
#      85         logger.info("""
#
# /Users/jacopo/openaigym/gym/gym/scoreboard/api.py in _upload(training_dir, algorithm_id, writeup, benchmark_run_id, api_key, ignore_open_monitors)
#     102             raise error.Error("Still have an open monitor on {}. You must run 'env.close()' before uploading.".format(', '.join(envs)))
#     103
# --> 104     env_info, training_episode_batch, training_video = upload_training_data(training_dir, api_key=api_key)
#     105     env_id = env_info['env_id']
#     106     training_episode_batch_id = training_video_id = None
#
# /Users/jacopo/openaigym/gym/gym/scoreboard/api.py in upload_training_data(training_dir, api_key)
#     158     # Do the relevant uploads
#     159     if len(episode_lengths) > 0:
# --> 160         training_episode_batch = upload_training_episode_batch(data_sources, episode_lengths, episode_rewards, episode_types, initial_reset_timestamps, timestamps, api_key, env_id=env_id)
#     161     else:
#     162         training_episode_batch = None
#
# /Users/jacopo/openaigym/gym/gym/scoreboard/api.py in upload_training_episode_batch(data_sources, episode_lengths, episode_rewards, episode_types, initial_reset_timestamps, timestamps, api_key, env_id)
#     176 def upload_training_episode_batch(data_sources, episode_lengths, episode_rewards, episode_types, initial_reset_timestamps, timestamps, api_key=None, env_id=None):
#     177     logger.info('[%s] Uploading %d episodes of training data', env_id, len(episode_lengths))
# --> 178     file_upload = resource.FileUpload.create(purpose='episode_batch', api_key=api_key)
#     179     file_upload.put({
#     180         'data_sources': data_sources,
#
# /Users/jacopo/openaigym/gym/gym/scoreboard/client/resource.py in create(cls, api_key, **params)
#     356         url = cls.class_path()
#     357         response, api_key = requestor.request(
# --> 358             'post', url, params=params)
#     359         return convert_to_gym_object(response, api_key)
#     360
#
# /Users/jacopo/openaigym/gym/gym/scoreboard/client/api_requestor.py in request(self, method, url, params, headers)
#      38     def request(self, method, url, params=None, headers=None):
#      39         rbody, rcode, rheaders, my_api_key = self.request_raw(
# ---> 40             method.lower(), url, params, headers)
#      41         resp = self.interpret_response(rbody, rcode, rheaders)
#      42         return resp, my_api_key
#
# /Users/jacopo/openaigym/gym/gym/scoreboard/client/api_requestor.py in request_raw(self, method, url, params, supplied_headers)
#      81             raise error.AuthenticationError("""You must provide an OpenAI Gym API key.
#      82
# ---> 83 (HINT: Set your API key using "gym.scoreboard.api_key = .." or "export OPENAI_GYM_API_KEY=..."). You can find your API key in the OpenAI Gym web interface: https://gym.openai.com/settings/profile.""")
#      84
#      85         abs_url = '%s%s' % (self.api_base, url)
#
# AuthenticationError: You must provide an OpenAI Gym API key.
#
# (HINT: Set your API key using "gym.scoreboard.api_key = .." or "export OPENAI_GYM_API_KEY=..."). You can find your API key in the OpenAI Gym web interface: https://gym.openai.com/settings/profile.

# %%
stats = calc_stats(er, el)

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
np.max(ts[0])
# Out:
# 1.0

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x1173b1f28>,
#  <matplotlib.figure.Figure at 0x122ae55c0>,
#  <matplotlib.figure.Figure at 0x11c52dcc0>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x11ff907f0>,
#  <matplotlib.figure.Figure at 0x11f724390>,
#  <matplotlib.figure.Figure at 0x11ffaf748>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x112be9dd8>,
#  <matplotlib.figure.Figure at 0x1242ca240>,
#  <matplotlib.figure.Figure at 0x12543a6a0>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x125030b70>,
#  <matplotlib.figure.Figure at 0x123d4bb70>,
#  <matplotlib.figure.Figure at 0x1250dce10>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x119b6e9e8>,
#  <matplotlib.figure.Figure at 0x117bc5c88>,
#  <matplotlib.figure.Figure at 0x116cf85c0>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x1216d2208>,
#  <matplotlib.figure.Figure at 0x117c156a0>,
#  <matplotlib.figure.Figure at 0x121b58cf8>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x114911b38>,
#  <matplotlib.figure.Figure at 0x114632b70>,
#  <matplotlib.figure.Figure at 0x114607be0>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x113373be0>,
#  <matplotlib.figure.Figure at 0x1133c6630>,
#  <matplotlib.figure.Figure at 0x1138e60f0>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x112f6e390>,
#  <matplotlib.figure.Figure at 0x1129cd898>,
#  <matplotlib.figure.Figure at 0x1132fe198>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x11c72ce48>,
#  <matplotlib.figure.Figure at 0x110f97ba8>,
#  <matplotlib.figure.Figure at 0x1271e8c18>)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x124690588>,
#  <matplotlib.figure.Figure at 0x11221ada0>,
#  <matplotlib.figure.Figure at 0x124585668>)
